# %%
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_community.embeddings import HuggingFaceEmbeddings
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY')

# %% [markdown]
# ### Extract PDFs

# %%
def load_pdf(data):
    loader = DirectoryLoader(data, glob='*.pdf', loader_cls=PyPDFLoader)
    document = loader.load()
    
    return document

# %%
extracted_data = load_pdf('../data')
# Out:
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 10 65536 (offset 0)
# Ignoring wrong pointing object 21 65536 (offset 0)
# Ignoring wrong pointing object 25 65536 (offset 0)
# Ignoring wrong pointing object 40 65536 (offset 0)
# Ignoring wrong pointing object 57 65536 (offset 0)
# Ignoring wrong pointing object 73 65536 (offset 0)
# Ignoring wrong pointing object 81 65536 (offset 0)
# Ignoring wrong pointing object 92 65536 (offset 0)
# Ignoring wrong pointing object 103 65536 (offset 0)
# Ignoring wrong pointing object 108 65536 (offset 0)
# Ignoring wrong pointing object 113 65536 (offset 0)
# Ignoring wrong pointing object 118 65536 (offset 0)
# Ignoring wrong pointing object 123 65536 (offset 0)
# Ignoring wrong pointing object 128 65536 (offset 0)
# Ignoring wrong pointing object 133 65536 (offset 0)
# Ignoring wrong pointing object 138 65536 (offset 0)
# Ignoring wrong pointing object 143 65536 (offset 0)
# Ignoring wrong pointing object 148 65536 (offset 0)
# Ignoring wrong pointing object 153 65536 (offset 0)
# Ignoring wrong pointing object 158 65536 (offset 0)
# Ignoring wrong pointing object 163 65536 (offset 0)
# Ignoring wrong pointing object 177 65536 (offset 0)
# Ignoring wrong pointing object 183 65536 (offset 0)
# Ignoring wrong pointing object 198 65536 (offset 0)
# Ignoring wrong pointing object 203 65536 (offset 0)
# Ignoring wrong pointing object 208 65536 (offset 0)
# Ignoring wrong pointing object 213 65536 (offset 0)
# Ignoring wrong pointing object 221 65536 (offset 0)
# Ignoring wrong pointing object 226 65536 (offset 0)
# Ignoring wrong pointing object 231 65536 (offset 0)
# Ignoring wrong pointing object 236 65536 (offset 0)
# Ignoring wrong pointing object 241 65536 (offset 0)
# Ignoring wrong pointing object 246 65536 (offset 0)
# Ignoring wrong pointing object 251 65536 (offset 0)
# Ignoring wrong pointing object 260 65536 (offset 0)
# Ignoring wrong pointing object 268 65536 (offset 0)
# Ignoring wrong pointing object 273 65536 (offset 0)
# Ignoring wrong pointing object 278 65536 (offset 0)
# Ignoring wrong pointing object 283 65536 (offset 0)
# Ignoring wrong pointing object 291 65536 (offset 0)
# Ignoring wrong pointing object 296 65536 (offset 0)
# Ignoring wrong pointing object 301 65536 (offset 0)
# Ignoring wrong pointing object 306 65536 (offset 0)
# Ignoring wrong pointing object 311 65536 (offset 0)
# Ignoring wrong pointing object 316 65536 (offset 0)
# Ignoring wrong pointing object 321 65536 (offset 0)
# Ignoring wrong pointing object 326 65536 (offset 0)
# Ignoring wrong pointing object 331 65536 (offset 0)
# Ignoring wrong pointing object 336 65536 (offset 0)
# Ignoring wrong pointing object 341 65536 (offset 0)
# Ignoring wrong pointing object 346 65536 (offset 0)
# Ignoring wrong pointing object 351 65536 (offset 0)
# Ignoring wrong pointing object 356 65536 (offset 0)
# Ignoring wrong pointing object 361 65536 (offset 0)
# Ignoring wrong pointing object 366 65536 (offset 0)
# Ignoring wrong pointing object 371 65536 (offset 0)
# Ignoring wrong pointing object 376 65536 (offset 0)
# Ignoring wrong pointing object 381 65536 (offset 0)
# Ignoring wrong pointing object 386 65536 (offset 0)
# Ignoring wrong pointing object 391 65536 (offset 0)
# Ignoring wrong pointing object 396 65536 (offset 0)
# Ignoring wrong pointing object 401 65536 (offset 0)
# Ignoring wrong pointing object 406 65536 (offset 0)
# Ignoring wrong pointing object 411 65536 (offset 0)
# Ignoring wrong pointing object 416 65536 (offset 0)
# Ignoring wrong pointing object 421 65536 (offset 0)
# Ignoring wrong pointing object 426 65536 (offset 0)
# Ignoring wrong pointing object 431 65536 (offset 0)
# Ignoring wrong pointing object 436 65536 (offset 0)
# Ignoring wrong pointing object 441 65536 (offset 0)
# Ignoring wrong pointing object 446 65536 (offset 0)
# Ignoring wrong pointing object 451 65536 (offset 0)
# Ignoring wrong pointing object 456 65536 (offset 0)
# Ignoring wrong pointing object 461 65536 (offset 0)
# Ignoring wrong pointing object 466 65536 (offset 0)
# Ignoring wrong pointing object 471 65536 (offset 0)
# Ignoring wrong pointing object 476 65536 (offset 0)
# Ignoring wrong pointing object 481 65536 (offset 0)
# Ignoring wrong pointing object 486 65536 (offset 0)
# Ignoring wrong pointing object 491 65536 (offset 0)
# Ignoring wrong pointing object 496 65536 (offset 0)
# Ignoring wrong pointing object 501 65536 (offset 0)
# Ignoring wrong pointing object 506 65536 (offset 0)
# Ignoring wrong pointing object 511 65536 (offset 0)
# Ignoring wrong pointing object 516 65536 (offset 0)
# Ignoring wrong pointing object 521 65536 (offset 0)
# Ignoring wrong pointing object 526 65536 (offset 0)
# Ignoring wrong pointing object 531 65536 (offset 0)
# Ignoring wrong pointing object 536 65536 (offset 0)
# Ignoring wrong pointing object 541 65536 (offset 0)
# Ignoring wrong pointing object 546 65536 (offset 0)
# Ignoring wrong pointing object 551 65536 (offset 0)
# Ignoring wrong pointing object 556 65536 (offset 0)
# Ignoring wrong pointing object 561 65536 (offset 0)
# Ignoring wrong pointing object 566 65536 (offset 0)
# Ignoring wrong pointing object 571 65536 (offset 0)
# Ignoring wrong pointing object 576 65536 (offset 0)
# Ignoring wrong pointing object 581 65536 (offset 0)
# Ignoring wrong pointing object 586 65536 (offset 0)
# Ignoring wrong pointing object 591 65536 (offset 0)
# Ignoring wrong pointing object 596 65536 (offset 0)
# Ignoring wrong pointing object 601 65536 (offset 0)
# Ignoring wrong pointing object 606 65536 (offset 0)
# Ignoring wrong pointing object 611 65536 (offset 0)
# Ignoring wrong pointing object 616 65536 (offset 0)
# Ignoring wrong pointing object 621 65536 (offset 0)
# Ignoring wrong pointing object 626 65536 (offset 0)
# Ignoring wrong pointing object 631 65536 (offset 0)
# Ignoring wrong pointing object 636 65536 (offset 0)
# Ignoring wrong pointing object 641 65536 (offset 0)
# Ignoring wrong pointing object 646 65536 (offset 0)
# Ignoring wrong pointing object 651 65536 (offset 0)
# Ignoring wrong pointing object 656 65536 (offset 0)
# Ignoring wrong pointing object 661 65536 (offset 0)
# Ignoring wrong pointing object 666 65536 (offset 0)
# Ignoring wrong pointing object 671 65536 (offset 0)
# Ignoring wrong pointing object 676 65536 (offset 0)
# Ignoring wrong pointing object 681 65536 (offset 0)
# Ignoring wrong pointing object 686 65536 (offset 0)
# Ignoring wrong pointing object 691 65536 (offset 0)
# Ignoring wrong pointing object 696 65536 (offset 0)
# Ignoring wrong pointing object 701 65536 (offset 0)
# Ignoring wrong pointing object 706 65536 (offset 0)
# Ignoring wrong pointing object 711 65536 (offset 0)
# Ignoring wrong pointing object 716 65536 (offset 0)
# Ignoring wrong pointing object 721 65536 (offset 0)
# Ignoring wrong pointing object 726 65536 (offset 0)
# Ignoring wrong pointing object 731 65536 (offset 0)
# Ignoring wrong pointing object 736 65536 (offset 0)
# Ignoring wrong pointing object 741 65536 (offset 0)
# Ignoring wrong pointing object 746 65536 (offset 0)
# Ignoring wrong pointing object 751 65536 (offset 0)
# Ignoring wrong pointing object 756 65536 (offset 0)
# Ignoring wrong pointing object 761 65536 (offset 0)
# Ignoring wrong pointing object 766 65536 (offset 0)
# Ignoring wrong pointing object 771 65536 (offset 0)
# Ignoring wrong pointing object 776 65536 (offset 0)
# Ignoring wrong pointing object 781 65536 (offset 0)
# Ignoring wrong pointing object 786 65536 (offset 0)
# Ignoring wrong pointing object 791 65536 (offset 0)
# Ignoring wrong pointing object 796 65536 (offset 0)
# Ignoring wrong pointing object 801 65536 (offset 0)
# Ignoring wrong pointing object 806 65536 (offset 0)
# Ignoring wrong pointing object 811 65536 (offset 0)
# Ignoring wrong pointing object 816 65536 (offset 0)
# Ignoring wrong pointing object 821 65536 (offset 0)
# Ignoring wrong pointing object 826 65536 (offset 0)
# Ignoring wrong pointing object 831 65536 (offset 0)
# Ignoring wrong pointing object 836 65536 (offset 0)
# Ignoring wrong pointing object 841 65536 (offset 0)
# Ignoring wrong pointing object 846 65536 (offset 0)
# Ignoring wrong pointing object 851 65536 (offset 0)
# Ignoring wrong pointing object 856 65536 (offset 0)
# Ignoring wrong pointing object 861 65536 (offset 0)
# Ignoring wrong pointing object 866 65536 (offset 0)
# Ignoring wrong pointing object 871 65536 (offset 0)
# Ignoring wrong pointing object 876 65536 (offset 0)
# Ignoring wrong pointing object 881 65536 (offset 0)
# Ignoring wrong pointing object 886 65536 (offset 0)
# Ignoring wrong pointing object 891 65536 (offset 0)
# Ignoring wrong pointing object 896 65536 (offset 0)
# Ignoring wrong pointing object 901 65536 (offset 0)
# Ignoring wrong pointing object 906 65536 (offset 0)
# Ignoring wrong pointing object 911 65536 (offset 0)
# Ignoring wrong pointing object 916 65536 (offset 0)
# Ignoring wrong pointing object 921 65536 (offset 0)
# Ignoring wrong pointing object 926 65536 (offset 0)
# Ignoring wrong pointing object 931 65536 (offset 0)
# Ignoring wrong pointing object 936 65536 (offset 0)
# Ignoring wrong pointing object 941 65536 (offset 0)
# Ignoring wrong pointing object 946 65536 (offset 0)
# Ignoring wrong pointing object 951 65536 (offset 0)
# Ignoring wrong pointing object 956 65536 (offset 0)
# Ignoring wrong pointing object 961 65536 (offset 0)
# Ignoring wrong pointing object 966 65536 (offset 0)
# Ignoring wrong pointing object 971 65536 (offset 0)
# Ignoring wrong pointing object 976 65536 (offset 0)
# Ignoring wrong pointing object 981 65536 (offset 0)
# Ignoring wrong pointing object 986 65536 (offset 0)
# Ignoring wrong pointing object 991 65536 (offset 0)
# Ignoring wrong pointing object 996 65536 (offset 0)
# Ignoring wrong pointing object 1001 65536 (offset 0)
# Ignoring wrong pointing object 1006 65536 (offset 0)
# Ignoring wrong pointing object 1011 65536 (offset 0)
# Ignoring wrong pointing object 1016 65536 (offset 0)
# Ignoring wrong pointing object 1021 65536 (offset 0)
# Ignoring wrong pointing object 1026 65536 (offset 0)
# Ignoring wrong pointing object 1031 65536 (offset 0)
# Ignoring wrong pointing object 1036 65536 (offset 0)
# Ignoring wrong pointing object 1041 65536 (offset 0)
# Ignoring wrong pointing object 1046 65536 (offset 0)
# Ignoring wrong pointing object 1051 65536 (offset 0)
# Ignoring wrong pointing object 1056 65536 (offset 0)
# Ignoring wrong pointing object 1061 65536 (offset 0)
# Ignoring wrong pointing object 1066 65536 (offset 0)
# Ignoring wrong pointing object 1071 65536 (offset 0)
# Ignoring wrong pointing object 1076 65536 (offset 0)
# Ignoring wrong pointing object 1081 65536 (offset 0)
# Ignoring wrong pointing object 1086 65536 (offset 0)
# Ignoring wrong pointing object 1091 65536 (offset 0)
# Ignoring wrong pointing object 1096 65536 (offset 0)
# Ignoring wrong pointing object 1101 65536 (offset 0)
# Ignoring wrong pointing object 1106 65536 (offset 0)
# Ignoring wrong pointing object 1111 65536 (offset 0)
# Ignoring wrong pointing object 1116 65536 (offset 0)
# Ignoring wrong pointing object 1121 65536 (offset 0)
# Ignoring wrong pointing object 1126 65536 (offset 0)
# Ignoring wrong pointing object 1131 65536 (offset 0)
# Ignoring wrong pointing object 1136 65536 (offset 0)
# Ignoring wrong pointing object 1141 65536 (offset 0)
# Ignoring wrong pointing object 1146 65536 (offset 0)
# Ignoring wrong pointing object 1151 65536 (offset 0)
# Ignoring wrong pointing object 1156 65536 (offset 0)
# Ignoring wrong pointing object 1161 65536 (offset 0)
# Ignoring wrong pointing object 1166 65536 (offset 0)
# Ignoring wrong pointing object 1171 65536 (offset 0)
# Ignoring wrong pointing object 1176 65536 (offset 0)
# Ignoring wrong pointing object 1181 65536 (offset 0)
# Ignoring wrong pointing object 1186 65536 (offset 0)
# Ignoring wrong pointing object 1191 65536 (offset 0)
# Ignoring wrong pointing object 1196 65536 (offset 0)
# Ignoring wrong pointing object 1201 65536 (offset 0)
# Ignoring wrong pointing object 1206 65536 (offset 0)
# Ignoring wrong pointing object 1211 65536 (offset 0)
# Ignoring wrong pointing object 1216 65536 (offset 0)
# Ignoring wrong pointing object 1221 65536 (offset 0)
# Ignoring wrong pointing object 1226 65536 (offset 0)
# Ignoring wrong pointing object 1231 65536 (offset 0)
# Ignoring wrong pointing object 1236 65536 (offset 0)
# Ignoring wrong pointing object 1241 65536 (offset 0)
# Ignoring wrong pointing object 1246 65536 (offset 0)
# Ignoring wrong pointing object 1269 65536 (offset 0)
# Ignoring wrong pointing object 1274 65536 (offset 0)
# Ignoring wrong pointing object 1279 65536 (offset 0)
# Ignoring wrong pointing object 1284 65536 (offset 0)
# Ignoring wrong pointing object 1289 65536 (offset 0)
# Ignoring wrong pointing object 1294 65536 (offset 0)
# Ignoring wrong pointing object 1299 65536 (offset 0)
# Ignoring wrong pointing object 1304 65536 (offset 0)
# Ignoring wrong pointing object 1309 65536 (offset 0)
# Ignoring wrong pointing object 1314 65536 (offset 0)
# Ignoring wrong pointing object 1319 65536 (offset 0)
# Ignoring wrong pointing object 1324 65536 (offset 0)
# Ignoring wrong pointing object 1329 65536 (offset 0)
# Ignoring wrong pointing object 1334 65536 (offset 0)
# Ignoring wrong pointing object 1339 65536 (offset 0)
# Ignoring wrong pointing object 1344 65536 (offset 0)
# Ignoring wrong pointing object 1349 65536 (offset 0)
# Ignoring wrong pointing object 1354 65536 (offset 0)
# Ignoring wrong pointing object 1359 65536 (offset 0)
# Ignoring wrong pointing object 1364 65536 (offset 0)
# Ignoring wrong pointing object 1369 65536 (offset 0)
# Ignoring wrong pointing object 1374 65536 (offset 0)
# Ignoring wrong pointing object 1379 65536 (offset 0)
# Ignoring wrong pointing object 1384 65536 (offset 0)
# Ignoring wrong pointing object 1389 65536 (offset 0)
# Ignoring wrong pointing object 1394 65536 (offset 0)
# Ignoring wrong pointing object 1399 65536 (offset 0)
# Ignoring wrong pointing object 1404 65536 (offset 0)
# Ignoring wrong pointing object 1409 65536 (offset 0)
# Ignoring wrong pointing object 1414 65536 (offset 0)
# Ignoring wrong pointing object 1419 65536 (offset 0)
# Ignoring wrong pointing object 1424 65536 (offset 0)
# Ignoring wrong pointing object 1429 65536 (offset 0)
# Ignoring wrong pointing object 1434 65536 (offset 0)
# Ignoring wrong pointing object 1439 65536 (offset 0)
# Ignoring wrong pointing object 1444 65536 (offset 0)
# Ignoring wrong pointing object 1449 65536 (offset 0)
# Ignoring wrong pointing object 1454 65536 (offset 0)
# Ignoring wrong pointing object 1464 65536 (offset 0)
# Ignoring wrong pointing object 1469 65536 (offset 0)
# Ignoring wrong pointing object 1474 65536 (offset 0)
# Ignoring wrong pointing object 1479 65536 (offset 0)
# Ignoring wrong pointing object 1484 65536 (offset 0)
# Ignoring wrong pointing object 1489 65536 (offset 0)
# Ignoring wrong pointing object 1494 65536 (offset 0)
# Ignoring wrong pointing object 1499 65536 (offset 0)
# Ignoring wrong pointing object 1504 65536 (offset 0)
# Ignoring wrong pointing object 1509 65536 (offset 0)
# Ignoring wrong pointing object 1514 65536 (offset 0)
# Ignoring wrong pointing object 1519 65536 (offset 0)
# Ignoring wrong pointing object 1524 65536 (offset 0)
# Ignoring wrong pointing object 1529 65536 (offset 0)
# Ignoring wrong pointing object 1534 65536 (offset 0)
# Ignoring wrong pointing object 1539 65536 (offset 0)
# Ignoring wrong pointing object 1544 65536 (offset 0)
# Ignoring wrong pointing object 1549 65536 (offset 0)
# Ignoring wrong pointing object 1554 65536 (offset 0)
# Ignoring wrong pointing object 1559 65536 (offset 0)
# Ignoring wrong pointing object 1564 65536 (offset 0)
# Ignoring wrong pointing object 1569 65536 (offset 0)
# Ignoring wrong pointing object 1574 65536 (offset 0)
# Ignoring wrong pointing object 1579 65536 (offset 0)
# Ignoring wrong pointing object 1584 65536 (offset 0)
# Ignoring wrong pointing object 1589 65536 (offset 0)
# Ignoring wrong pointing object 1594 65536 (offset 0)
# Ignoring wrong pointing object 1599 65536 (offset 0)
# Ignoring wrong pointing object 1604 65536 (offset 0)
# Ignoring wrong pointing object 1609 65536 (offset 0)
# Ignoring wrong pointing object 1614 65536 (offset 0)
# Ignoring wrong pointing object 1619 65536 (offset 0)
# Ignoring wrong pointing object 1624 65536 (offset 0)
# Ignoring wrong pointing object 1629 65536 (offset 0)
# Ignoring wrong pointing object 1634 65536 (offset 0)
# Ignoring wrong pointing object 1639 65536 (offset 0)
# Ignoring wrong pointing object 1644 65536 (offset 0)
# Ignoring wrong pointing object 1649 65536 (offset 0)
# Ignoring wrong pointing object 1654 65536 (offset 0)
# Ignoring wrong pointing object 1659 65536 (offset 0)
# Ignoring wrong pointing object 1664 65536 (offset 0)
# Ignoring wrong pointing object 1669 65536 (offset 0)
# Ignoring wrong pointing object 1674 65536 (offset 0)
# Ignoring wrong pointing object 1679 65536 (offset 0)
# Ignoring wrong pointing object 1684 65536 (offset 0)
# Ignoring wrong pointing object 1689 65536 (offset 0)
# Ignoring wrong pointing object 1694 65536 (offset 0)
# Ignoring wrong pointing object 1699 65536 (offset 0)
# Ignoring wrong pointing object 1704 65536 (offset 0)
# Ignoring wrong pointing object 1709 65536 (offset 0)
# Ignoring wrong pointing object 1714 65536 (offset 0)
# Ignoring wrong pointing object 1719 65536 (offset 0)
# Ignoring wrong pointing object 1724 65536 (offset 0)
# Ignoring wrong pointing object 1729 65536 (offset 0)
# Ignoring wrong pointing object 1734 65536 (offset 0)
# Ignoring wrong pointing object 1739 65536 (offset 0)
# Ignoring wrong pointing object 1744 65536 (offset 0)
# Ignoring wrong pointing object 1749 65536 (offset 0)
# Ignoring wrong pointing object 1754 65536 (offset 0)
# Ignoring wrong pointing object 1759 65536 (offset 0)
# Ignoring wrong pointing object 1764 65536 (offset 0)
# Ignoring wrong pointing object 1769 65536 (offset 0)
# Ignoring wrong pointing object 1774 65536 (offset 0)
# Ignoring wrong pointing object 1779 65536 (offset 0)
# Ignoring wrong pointing object 1784 65536 (offset 0)
# Ignoring wrong pointing object 1789 65536 (offset 0)
# Ignoring wrong pointing object 1794 65536 (offset 0)
# Ignoring wrong pointing object 1799 65536 (offset 0)
# Ignoring wrong pointing object 1804 65536 (offset 0)
# Ignoring wrong pointing object 1809 65536 (offset 0)
# Ignoring wrong pointing object 1814 65536 (offset 0)
# Ignoring wrong pointing object 1819 65536 (offset 0)
# Ignoring wrong pointing object 1824 65536 (offset 0)
# Ignoring wrong pointing object 1829 65536 (offset 0)
# Ignoring wrong pointing object 1834 65536 (offset 0)
# Ignoring wrong pointing object 1839 65536 (offset 0)
# Ignoring wrong pointing object 1844 65536 (offset 0)
# Ignoring wrong pointing object 1849 65536 (offset 0)
# Ignoring wrong pointing object 1854 65536 (offset 0)
# Ignoring wrong pointing object 1859 65536 (offset 0)
# Ignoring wrong pointing object 1864 65536 (offset 0)
# Ignoring wrong pointing object 1869 65536 (offset 0)
# Ignoring wrong pointing object 1874 65536 (offset 0)
# Ignoring wrong pointing object 1879 65536 (offset 0)
# Ignoring wrong pointing object 1884 65536 (offset 0)
# Ignoring wrong pointing object 1889 65536 (offset 0)
# Ignoring wrong pointing object 1894 65536 (offset 0)
# Ignoring wrong pointing object 1899 65536 (offset 0)
# Ignoring wrong pointing object 1904 65536 (offset 0)
# Ignoring wrong pointing object 1909 65536 (offset 0)
# Ignoring wrong pointing object 1914 65536 (offset 0)
# Ignoring wrong pointing object 1919 65536 (offset 0)
# Ignoring wrong pointing object 1924 65536 (offset 0)
# Ignoring wrong pointing object 1929 65536 (offset 0)
# Ignoring wrong pointing object 1934 65536 (offset 0)
# Ignoring wrong pointing object 1939 65536 (offset 0)
# Ignoring wrong pointing object 1944 65536 (offset 0)
# Ignoring wrong pointing object 1949 65536 (offset 0)
# Ignoring wrong pointing object 1954 65536 (offset 0)
# Ignoring wrong pointing object 1959 65536 (offset 0)
# Ignoring wrong pointing object 1964 65536 (offset 0)
# Ignoring wrong pointing object 1969 65536 (offset 0)
# Ignoring wrong pointing object 1974 65536 (offset 0)
# Ignoring wrong pointing object 1979 65536 (offset 0)
# Ignoring wrong pointing object 1984 65536 (offset 0)
# Ignoring wrong pointing object 1989 65536 (offset 0)
# Ignoring wrong pointing object 1994 65536 (offset 0)
# Ignoring wrong pointing object 1999 65536 (offset 0)
# Ignoring wrong pointing object 2004 65536 (offset 0)
# Ignoring wrong pointing object 2009 65536 (offset 0)
# Ignoring wrong pointing object 2014 65536 (offset 0)
# Ignoring wrong pointing object 2019 65536 (offset 0)
# Ignoring wrong pointing object 2024 65536 (offset 0)
# Ignoring wrong pointing object 2029 65536 (offset 0)
# Ignoring wrong pointing object 2034 65536 (offset 0)
# Ignoring wrong pointing object 2039 65536 (offset 0)
# Ignoring wrong pointing object 2044 65536 (offset 0)
# Ignoring wrong pointing object 2049 65536 (offset 0)
# Ignoring wrong pointing object 2054 65536 (offset 0)
# Ignoring wrong pointing object 2059 65536 (offset 0)
# Ignoring wrong pointing object 2064 65536 (offset 0)
# Ignoring wrong pointing object 2069 65536 (offset 0)
# Ignoring wrong pointing object 2074 65536 (offset 0)
# Ignoring wrong pointing object 2079 65536 (offset 0)
# Ignoring wrong pointing object 2084 65536 (offset 0)
# Ignoring wrong pointing object 2089 65536 (offset 0)
# Ignoring wrong pointing object 2094 65536 (offset 0)
# Ignoring wrong pointing object 2099 65536 (offset 0)
# Ignoring wrong pointing object 2104 65536 (offset 0)
# Ignoring wrong pointing object 2109 65536 (offset 0)
# Ignoring wrong pointing object 2114 65536 (offset 0)
# Ignoring wrong pointing object 2119 65536 (offset 0)
# Ignoring wrong pointing object 2124 65536 (offset 0)
# Ignoring wrong pointing object 2129 65536 (offset 0)
# Ignoring wrong pointing object 2134 65536 (offset 0)
# Ignoring wrong pointing object 2139 65536 (offset 0)
# Ignoring wrong pointing object 2144 65536 (offset 0)
# Ignoring wrong pointing object 2149 65536 (offset 0)
# Ignoring wrong pointing object 2172 65536 (offset 0)
# Ignoring wrong pointing object 2177 65536 (offset 0)
# Ignoring wrong pointing object 2182 65536 (offset 0)
# Ignoring wrong pointing object 2187 65536 (offset 0)
# Ignoring wrong pointing object 2192 65536 (offset 0)
# Ignoring wrong pointing object 2197 65536 (offset 0)
# Ignoring wrong pointing object 2202 65536 (offset 0)
# Ignoring wrong pointing object 2207 65536 (offset 0)
# Ignoring wrong pointing object 2212 65536 (offset 0)
# Ignoring wrong pointing object 2217 65536 (offset 0)
# Ignoring wrong pointing object 2222 65536 (offset 0)
# Ignoring wrong pointing object 2227 65536 (offset 0)
# Ignoring wrong pointing object 2232 65536 (offset 0)
# Ignoring wrong pointing object 2237 65536 (offset 0)
# Ignoring wrong pointing object 2242 65536 (offset 0)
# Ignoring wrong pointing object 2247 65536 (offset 0)
# Ignoring wrong pointing object 2252 65536 (offset 0)
# Ignoring wrong pointing object 2257 65536 (offset 0)
# Ignoring wrong pointing object 2262 65536 (offset 0)
# Ignoring wrong pointing object 2267 65536 (offset 0)
# Ignoring wrong pointing object 2272 65536 (offset 0)
# Ignoring wrong pointing object 2277 65536 (offset 0)
# Ignoring wrong pointing object 2282 65536 (offset 0)
# Ignoring wrong pointing object 2287 65536 (offset 0)
# Ignoring wrong pointing object 2292 65536 (offset 0)
# Ignoring wrong pointing object 2297 65536 (offset 0)
# Ignoring wrong pointing object 2302 65536 (offset 0)
# Ignoring wrong pointing object 2307 65536 (offset 0)
# Ignoring wrong pointing object 2312 65536 (offset 0)
# Ignoring wrong pointing object 2317 65536 (offset 0)
# Ignoring wrong pointing object 2322 65536 (offset 0)
# Ignoring wrong pointing object 2327 65536 (offset 0)
# Ignoring wrong pointing object 2332 65536 (offset 0)
# Ignoring wrong pointing object 2337 65536 (offset 0)
# Ignoring wrong pointing object 2346 65536 (offset 0)
# Ignoring wrong pointing object 2351 65536 (offset 0)
# Ignoring wrong pointing object 2356 65536 (offset 0)
# Ignoring wrong pointing object 2361 65536 (offset 0)
# Ignoring wrong pointing object 2366 65536 (offset 0)
# Ignoring wrong pointing object 2371 65536 (offset 0)
# Ignoring wrong pointing object 2376 65536 (offset 0)
# Ignoring wrong pointing object 2381 65536 (offset 0)
# Ignoring wrong pointing object 2386 65536 (offset 0)
# Ignoring wrong pointing object 2391 65536 (offset 0)
# Ignoring wrong pointing object 2396 65536 (offset 0)
# Ignoring wrong pointing object 2401 65536 (offset 0)
# Ignoring wrong pointing object 2406 65536 (offset 0)
# Ignoring wrong pointing object 2411 65536 (offset 0)
# Ignoring wrong pointing object 2416 65536 (offset 0)
# Ignoring wrong pointing object 2421 65536 (offset 0)
# Ignoring wrong pointing object 2426 65536 (offset 0)
# Ignoring wrong pointing object 2431 65536 (offset 0)
# Ignoring wrong pointing object 2436 65536 (offset 0)
# Ignoring wrong pointing object 2441 65536 (offset 0)
# Ignoring wrong pointing object 2446 65536 (offset 0)
# Ignoring wrong pointing object 2451 65536 (offset 0)
# Ignoring wrong pointing object 2456 65536 (offset 0)
# Ignoring wrong pointing object 2461 65536 (offset 0)
# Ignoring wrong pointing object 2466 65536 (offset 0)
# Ignoring wrong pointing object 2471 65536 (offset 0)
# Ignoring wrong pointing object 2476 65536 (offset 0)
# Ignoring wrong pointing object 2481 65536 (offset 0)
# Ignoring wrong pointing object 2486 65536 (offset 0)
# Ignoring wrong pointing object 2491 65536 (offset 0)
# Ignoring wrong pointing object 2496 65536 (offset 0)
# Ignoring wrong pointing object 2501 65536 (offset 0)
# Ignoring wrong pointing object 2506 65536 (offset 0)
# Ignoring wrong pointing object 2511 65536 (offset 0)
# Ignoring wrong pointing object 2516 65536 (offset 0)
# Ignoring wrong pointing object 2521 65536 (offset 0)
# Ignoring wrong pointing object 2526 65536 (offset 0)
# Ignoring wrong pointing object 2531 65536 (offset 0)
# Ignoring wrong pointing object 2536 65536 (offset 0)
# Ignoring wrong pointing object 2541 65536 (offset 0)
# Ignoring wrong pointing object 2546 65536 (offset 0)
# Ignoring wrong pointing object 2551 65536 (offset 0)
# Ignoring wrong pointing object 2556 65536 (offset 0)
# Ignoring wrong pointing object 2561 65536 (offset 0)
# Ignoring wrong pointing object 2566 65536 (offset 0)
# Ignoring wrong pointing object 2571 65536 (offset 0)
# Ignoring wrong pointing object 2576 65536 (offset 0)
# Ignoring wrong pointing object 2581 65536 (offset 0)
# Ignoring wrong pointing object 2586 65536 (offset 0)
# Ignoring wrong pointing object 2591 65536 (offset 0)
# Ignoring wrong pointing object 2596 65536 (offset 0)
# Ignoring wrong pointing object 2601 65536 (offset 0)
# Ignoring wrong pointing object 2606 65536 (offset 0)
# Ignoring wrong pointing object 2611 65536 (offset 0)
# Ignoring wrong pointing object 2616 65536 (offset 0)
# Ignoring wrong pointing object 2621 65536 (offset 0)
# Ignoring wrong pointing object 2626 65536 (offset 0)
# Ignoring wrong pointing object 2631 65536 (offset 0)
# Ignoring wrong pointing object 2636 65536 (offset 0)
# Ignoring wrong pointing object 2641 65536 (offset 0)
# Ignoring wrong pointing object 2646 65536 (offset 0)
# Ignoring wrong pointing object 2651 65536 (offset 0)
# Ignoring wrong pointing object 2656 65536 (offset 0)
# Ignoring wrong pointing object 2661 65536 (offset 0)
# Ignoring wrong pointing object 2666 65536 (offset 0)
# Ignoring wrong pointing object 2671 65536 (offset 0)
# Ignoring wrong pointing object 2676 65536 (offset 0)
# Ignoring wrong pointing object 2681 65536 (offset 0)
# Ignoring wrong pointing object 2686 65536 (offset 0)
# Ignoring wrong pointing object 2691 65536 (offset 0)
# Ignoring wrong pointing object 2696 65536 (offset 0)
# Ignoring wrong pointing object 2701 65536 (offset 0)
# Ignoring wrong pointing object 2706 65536 (offset 0)
# Ignoring wrong pointing object 2711 65536 (offset 0)
# Ignoring wrong pointing object 2716 65536 (offset 0)
# Ignoring wrong pointing object 2721 65536 (offset 0)
# Ignoring wrong pointing object 2726 65536 (offset 0)
# Ignoring wrong pointing object 2731 65536 (offset 0)
# Ignoring wrong pointing object 2736 65536 (offset 0)
# Ignoring wrong pointing object 2741 65536 (offset 0)
# Ignoring wrong pointing object 2746 65536 (offset 0)
# Ignoring wrong pointing object 2751 65536 (offset 0)
# Ignoring wrong pointing object 2756 65536 (offset 0)
# Ignoring wrong pointing object 2761 65536 (offset 0)
# Ignoring wrong pointing object 2766 65536 (offset 0)
# Ignoring wrong pointing object 2771 65536 (offset 0)
# Ignoring wrong pointing object 2776 65536 (offset 0)
# Ignoring wrong pointing object 2781 65536 (offset 0)
# Ignoring wrong pointing object 2786 65536 (offset 0)
# Ignoring wrong pointing object 2791 65536 (offset 0)
# Ignoring wrong pointing object 2796 65536 (offset 0)
# Ignoring wrong pointing object 2801 65536 (offset 0)
# Ignoring wrong pointing object 2806 65536 (offset 0)
# Ignoring wrong pointing object 2811 65536 (offset 0)
# Ignoring wrong pointing object 2816 65536 (offset 0)
# Ignoring wrong pointing object 2821 65536 (offset 0)
# Ignoring wrong pointing object 2826 65536 (offset 0)
# Ignoring wrong pointing object 2831 65536 (offset 0)
# Ignoring wrong pointing object 2836 65536 (offset 0)
# Ignoring wrong pointing object 2841 65536 (offset 0)
# Ignoring wrong pointing object 2846 65536 (offset 0)
# Ignoring wrong pointing object 2851 65536 (offset 0)
# Ignoring wrong pointing object 2856 65536 (offset 0)
# Ignoring wrong pointing object 2861 65536 (offset 0)
# Ignoring wrong pointing object 2866 65536 (offset 0)
# Ignoring wrong pointing object 2871 65536 (offset 0)
# Ignoring wrong pointing object 2876 65536 (offset 0)
# Ignoring wrong pointing object 2881 65536 (offset 0)
# Ignoring wrong pointing object 2886 65536 (offset 0)
# Ignoring wrong pointing object 2891 65536 (offset 0)
# Ignoring wrong pointing object 2896 65536 (offset 0)
# Ignoring wrong pointing object 2901 65536 (offset 0)
# Ignoring wrong pointing object 2906 65536 (offset 0)
# Ignoring wrong pointing object 2911 65536 (offset 0)
# Ignoring wrong pointing object 2916 65536 (offset 0)
# Ignoring wrong pointing object 2921 65536 (offset 0)
# Ignoring wrong pointing object 2926 65536 (offset 0)
# Ignoring wrong pointing object 2931 65536 (offset 0)
# Ignoring wrong pointing object 2936 65536 (offset 0)
# Ignoring wrong pointing object 2941 65536 (offset 0)
# Ignoring wrong pointing object 2946 65536 (offset 0)
# Ignoring wrong pointing object 2951 65536 (offset 0)
# Ignoring wrong pointing object 2956 65536 (offset 0)
# Ignoring wrong pointing object 2961 65536 (offset 0)
# Ignoring wrong pointing object 2966 65536 (offset 0)
# Ignoring wrong pointing object 2971 65536 (offset 0)
# Ignoring wrong pointing object 2976 65536 (offset 0)
# Ignoring wrong pointing object 2981 65536 (offset 0)
# Ignoring wrong pointing object 2986 65536 (offset 0)
# Ignoring wrong pointing object 2991 65536 (offset 0)
# Ignoring wrong pointing object 2996 65536 (offset 0)
# Ignoring wrong pointing object 3001 65536 (offset 0)
# Ignoring wrong pointing object 3006 65536 (offset 0)
# Ignoring wrong pointing object 3011 65536 (offset 0)
# Ignoring wrong pointing object 3016 65536 (offset 0)
# Ignoring wrong pointing object 3021 65536 (offset 0)
# Ignoring wrong pointing object 3026 65536 (offset 0)
# Ignoring wrong pointing object 3031 65536 (offset 0)
# Ignoring wrong pointing object 3036 65536 (offset 0)
# Ignoring wrong pointing object 3041 65536 (offset 0)
# Ignoring wrong pointing object 3046 65536 (offset 0)
# Ignoring wrong pointing object 3051 65536 (offset 0)
# Ignoring wrong pointing object 3056 65536 (offset 0)
# Ignoring wrong pointing object 3061 65536 (offset 0)
# Ignoring wrong pointing object 3066 65536 (offset 0)
# Ignoring wrong pointing object 3071 65536 (offset 0)
# Ignoring wrong pointing object 3076 65536 (offset 0)
# Ignoring wrong pointing object 3093 65536 (offset 0)
# Ignoring wrong pointing object 3104 65536 (offset 0)
# Ignoring wrong pointing object 3109 65536 (offset 0)
# Ignoring wrong pointing object 3114 65536 (offset 0)
# Ignoring wrong pointing object 3119 65536 (offset 0)
# Ignoring wrong pointing object 3124 65536 (offset 0)
# Ignoring wrong pointing object 3129 65536 (offset 0)
# Ignoring wrong pointing object 3134 65536 (offset 0)
# Ignoring wrong pointing object 3139 65536 (offset 0)
# Ignoring wrong pointing object 3144 65536 (offset 0)
# Ignoring wrong pointing object 3149 65536 (offset 0)
# Ignoring wrong pointing object 3154 65536 (offset 0)
# Ignoring wrong pointing object 3159 65536 (offset 0)
# Ignoring wrong pointing object 3164 65536 (offset 0)
# Ignoring wrong pointing object 3169 65536 (offset 0)
# Ignoring wrong pointing object 3174 65536 (offset 0)
# Ignoring wrong pointing object 3179 65536 (offset 0)
# Ignoring wrong pointing object 3184 65536 (offset 0)
# Ignoring wrong pointing object 3189 65536 (offset 0)
# Ignoring wrong pointing object 3194 65536 (offset 0)
# Ignoring wrong pointing object 3199 65536 (offset 0)
# Ignoring wrong pointing object 3204 65536 (offset 0)
# Ignoring wrong pointing object 3209 65536 (offset 0)
# Ignoring wrong pointing object 3214 65536 (offset 0)
# Ignoring wrong pointing object 3219 65536 (offset 0)
# Ignoring wrong pointing object 3224 65536 (offset 0)
# Ignoring wrong pointing object 3229 65536 (offset 0)
# Ignoring wrong pointing object 3234 65536 (offset 0)
# Ignoring wrong pointing object 3239 65536 (offset 0)
# Ignoring wrong pointing object 3244 65536 (offset 0)
# Ignoring wrong pointing object 3249 65536 (offset 0)
# Ignoring wrong pointing object 3254 65536 (offset 0)
# Ignoring wrong pointing object 3259 65536 (offset 0)
# Ignoring wrong pointing object 3264 65536 (offset 0)
# Ignoring wrong pointing object 3269 65536 (offset 0)
# Ignoring wrong pointing object 3274 65536 (offset 0)
# Ignoring wrong pointing object 3279 65536 (offset 0)
# Ignoring wrong pointing object 3284 65536 (offset 0)
# Ignoring wrong pointing object 3289 65536 (offset 0)
# Ignoring wrong pointing object 3294 65536 (offset 0)
# Ignoring wrong pointing object 3299 65536 (offset 0)
# Ignoring wrong pointing object 3304 65536 (offset 0)
# Ignoring wrong pointing object 3309 65536 (offset 0)
# Ignoring wrong pointing object 3314 65536 (offset 0)
# Ignoring wrong pointing object 3319 65536 (offset 0)
# Ignoring wrong pointing object 3324 65536 (offset 0)
# Ignoring wrong pointing object 3335 65536 (offset 0)
# Ignoring wrong pointing object 3340 65536 (offset 0)
# Ignoring wrong pointing object 3345 65536 (offset 0)
# Ignoring wrong pointing object 3350 65536 (offset 0)
# Ignoring wrong pointing object 3355 65536 (offset 0)
# Ignoring wrong pointing object 3360 65536 (offset 0)
# Ignoring wrong pointing object 3365 65536 (offset 0)
# Ignoring wrong pointing object 3370 65536 (offset 0)
# Ignoring wrong pointing object 3375 65536 (offset 0)
# Ignoring wrong pointing object 3380 65536 (offset 0)
# Ignoring wrong pointing object 3385 65536 (offset 0)
# Ignoring wrong pointing object 3390 65536 (offset 0)
# Ignoring wrong pointing object 3395 65536 (offset 0)
# Ignoring wrong pointing object 3400 65536 (offset 0)
# Ignoring wrong pointing object 3405 65536 (offset 0)
# Ignoring wrong pointing object 3410 65536 (offset 0)
# Ignoring wrong pointing object 3415 65536 (offset 0)
# Ignoring wrong pointing object 3420 65536 (offset 0)
# Ignoring wrong pointing object 3425 65536 (offset 0)
# Ignoring wrong pointing object 3430 65536 (offset 0)
# Ignoring wrong pointing object 3435 65536 (offset 0)
# Ignoring wrong pointing object 3440 65536 (offset 0)
# Ignoring wrong pointing object 3445 65536 (offset 0)
# Ignoring wrong pointing object 3450 65536 (offset 0)
# Ignoring wrong pointing object 3455 65536 (offset 0)
# Ignoring wrong pointing object 3460 65536 (offset 0)
# Ignoring wrong pointing object 3465 65536 (offset 0)
# Ignoring wrong pointing object 3470 65536 (offset 0)
# Ignoring wrong pointing object 3475 65536 (offset 0)
# Ignoring wrong pointing object 3480 65536 (offset 0)
# Ignoring wrong pointing object 3485 65536 (offset 0)
# Ignoring wrong pointing object 3490 65536 (offset 0)
# Ignoring wrong pointing object 3495 65536 (offset 0)
# Ignoring wrong pointing object 3500 65536 (offset 0)
# Ignoring wrong pointing object 3505 65536 (offset 0)
# Ignoring wrong pointing object 3510 65536 (offset 0)
# Ignoring wrong pointing object 3515 65536 (offset 0)
# Ignoring wrong pointing object 3520 65536 (offset 0)
# Ignoring wrong pointing object 3525 65536 (offset 0)
# Ignoring wrong pointing object 3530 65536 (offset 0)
# Ignoring wrong pointing object 3535 65536 (offset 0)
# Ignoring wrong pointing object 3540 65536 (offset 0)
# Ignoring wrong pointing object 3545 65536 (offset 0)
# Ignoring wrong pointing object 3553 65536 (offset 0)
# Ignoring wrong pointing object 3558 65536 (offset 0)
# Ignoring wrong pointing object 3563 65536 (offset 0)
# Ignoring wrong pointing object 3568 65536 (offset 0)
# Ignoring wrong pointing object 3573 65536 (offset 0)
# Ignoring wrong pointing object 3578 65536 (offset 0)
# Ignoring wrong pointing object 3583 65536 (offset 0)
# Ignoring wrong pointing object 3588 65536 (offset 0)
# Ignoring wrong pointing object 3593 65536 (offset 0)
# Ignoring wrong pointing object 3598 65536 (offset 0)
# Ignoring wrong pointing object 3603 65536 (offset 0)
# Ignoring wrong pointing object 3608 65536 (offset 0)
# Ignoring wrong pointing object 3613 65536 (offset 0)
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet
# Advanced encoding [] not implemented yet

# %% [markdown]
# ### Creating text chunks

# %%
def text_split(extracted_data):
    splited_text = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=20)
    text_chunk = splited_text.split_documents(extracted_data)
    
    return text_chunk

# %%
text_chunk = text_split(extracted_data)
len(text_chunk)
# Out:
# 5862

# %% [markdown]
# ### Download HuggingFace Embedding

# %%
def download_hf_embeddings():
    embedding = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embedding

# %%
embedding = download_hf_embeddings()

# %%
embedding
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %% [markdown]
# ### Pinecone Database

# %%
# Create the Pinecone client
pc = Pinecone(api_key=PINECONE_API_KEY)

# Access the index
index = pc.Index("qchatbot")

# %%
texts = [t.page_content for t in text_chunk]

# Create or connect to the vector store
doc_search = PineconeVectorStore.from_texts(
    texts=texts,
    embedding=embedding,
    index_name="qchatbot",
    namespace="default"  # optional
)

# %% [markdown]
# ### Similarity search

# %%
query = "What is reversible gate?"
docs = doc_search.similarity_search(query=query, k=3)
print(docs)
# Out:
# [Document(id='fc161a24-c7ac-4aae-88d9-f6f7a4f5285f', metadata={}, page_content='A reversible gate, is a logic gate where, given the output(s) of the gate, we can\nalways determine what the input(s) was (were). An example is the NOT gate:'), Document(id='910b6f05-c254-4b3f-85e3-c3a99af1e133', metadata={}, page_content='1.5 Reversible Logic Gates 49\nWe can generalize this technique several ways. First, the gate could be a function\nof any number of variables. For example, say we have a gate with three inputsA, B,\nC, and one output f (A,B,C):\nGate\nA\nB\nC\nf(A, B, C)\nThis must be irreversible because there are fewer outputs than inputs. To make it\nreversible, we add a fourth input D that we XOR with f (A,B,C):\nA A\nB B'), Document(id='a1d6dd9b-7952-4e71-a575-db709b6dd67f', metadata={}, page_content='Another way to contrast reversible and irreversible gates is whether information\nis lost. With a reversible gate, no information is lost since we can always recover\nthe inputs from the outputs. With an irreversible gate, however, information is lost\nsince, given an output, we generally do not know what the inputs were.')]

# %%
template = """
You are a knowledgeable quantum assistant focused strictly on topics related to **quantum mechanics** and **quantum computing**.

Use the provided context to answer the user's question. If the context does not contain relevant information to answer the question, respond with:
**"I'm not sure about that based on the information I have."**

Strictly avoid making up information or answering unrelated topics.

Context:
{context}

Question:
{question}

Answer:
""".strip()

# %%
PROMPT = PromptTemplate(
    template=template,
    input_variables=["context", "question"]
    )

chain_type_kwargs = {'prompt': PROMPT}

# %%
llm = ChatOpenAI(
    openai_api_key=OPENROUTER_API_KEY,
    openai_api_base="https://openrouter.ai/api/v1",
    model_name="shisa-ai/shisa-v2-llama3.3-70b:free",
    temperature=0.5,
)

# %%
qna = RetrievalQA.from_chain_type(llm=llm,
                                  chain_type='stuff',
                                  retriever=doc_search.as_retriever(search_kwargs={'k':2}),
                                  return_source_documents=True,
                                  chain_type_kwargs=chain_type_kwargs
                                  )

# %%
while True:
    user_input = input(f"Input Prompt: ")
    result=qna({'query':user_input})
    
    print(result['result'])
# Out:
# C:\Users\Durjay\AppData\Local\Temp\ipykernel_4716\3434308939.py:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result=qna({'query':user_input})
# A reversible gate is a logic gate where, given the output(s) of the gate, we can always determine what the input(s) was (were). This means that the gate’s operation can be inverted to recover the original inputs from the outputs, ensuring no information is lost during the computation.
#
# For example, the NOT gate is a simple reversible gate because knowing the output allows us to uniquely determine the input.
#
# More generally, a reversible gate must have at least as many outputs as inputs to avoid information loss. If a gate has fewer outputs than inputs (like the example with inputs *A, B, C* and one output *f(A, B, C)*), it is irreversible because multiple input combinations could produce the same output.
#
# To make such a gate reversible, additional inputs (or "ancillary bits") can be introduced, such as in the modified example where a fourth input *D* is XORed with *f(A, B, C)* to ensure reversibility.
# Here are five examples of reversible logic gates based on the given context:
#
# 1. **Toffoli Gate (3 inputs, 3 outputs)**
#    - Inputs: A, B, C
#    - Outputs: A, B, AB ⊕ C
#
# 2. **Reversible XOR Gate (2 inputs, 2 outputs)**
#    - Inputs: A, B
#    - Outputs: A, A ⊕ B
#
# 3. **Reversible AND Gate (3 inputs, 3 outputs)**
#    - Inputs: A, B, C
#    - Outputs: A, B, (A ∧ B) ⊕ C
#
# 4. **Reversible OR Gate (3 inputs, 3 outputs)**
#    - Inputs: A, B, C
#    - Outputs: A, B, (A ∨ B) ⊕ C
#
# 5. **Reversible NOT Gate (2 inputs, 2 outputs)**
#    - Inputs: A, B
#    - Outputs: A, ¬A ⊕ B
#
# Each of these gates maintains reversibility by ensuring the number of outputs matches the number of inputs, and the transformation is invertible. Let me know if you'd like further details on any of these!
# Grover’s algorithm is a quantum algorithm that solves the unstructured search problem quadratically faster than any classical algorithm. Given an unsorted database of *N* entries, it finds a specific entry (the "marked" state |w⟩) in approximately *O(√N)* queries, while a classical algorithm would require *O(N)* queries on average.
#
# The algorithm works by:
# 1. Initializing a superposition of all possible states.
# 2. Applying an oracle that marks the target state |w⟩ by flipping its phase.
# 3. Amplifying the marked state using the Grover iterator (a combination of the oracle and a diffusion operator).
# 4. Measuring the final state to obtain |w⟩ with high probability.
#
# The algorithm is optimal because no quantum algorithm can solve this problem faster than *O(√N)* due to fundamental limits imposed by quantum mechanics.
